# %% [markdown]
# ### Initialization:
#
# - python: 3.7.0
# - environment: recommendations

# %% [markdown]
# ### Install packages

# %%
# !pip3 install pandas
# !pip3 install feedparser
# !pip3 install beautifulsoup4
# !pip3 install Scrapy
# !pip3 install newspaper3k
# !pip3 install lxml

# %% [markdown]
# ### Detailed Steps:
#
# - Step 1: Include all the packages here.
# - Step 2: Initialise variables to hold all article links, raw and scrubbed contents.
# - Step 3: Retrieve all the articles links from a blog provided.
# - Step 4: Crawl all articles links to retrieve all title, content and link accordingly.
# - Step 5: Save raw content in `raw_machine_learning_mastery.json` and scrubbed content in `scrubbed_machine_learning_mastery.json` files accordingly.

# %%
### Step 1: Import necessary packages here ###

import csv
import pandas
import numpy

# feedparser helps to xml to hash
# Install: conda install feedparser
import feedparser

# BeautifulSoup helps to grab text out of html
# Install: conda install beautifulsoup4
from bs4 import BeautifulSoup

import json
import urllib3

from collections import Counter

import scrapy
import newspaper
from newspaper import Article
from pandas import read_csv
from lxml import html
import requests

# %%
### Step 2: Initialise variables to store raw article, scrubbed article & article links.

# for raw article
raw_json = list()

# for scrubbed article
scrubbed_json = list()

# for article links
article_links = list()

# %%
### Step 3: Feed in the blog URL to aggregate content ###
# 2.1 Select the blog that we want to crawl.
# 2.2 Grab all article links from the current page.
# 2.3 Crawl pages until we reach at a page that returns empty results.

feed_url = "http://machinelearningmastery.com/blog/"
urllib3.disable_warnings()
http = urllib3.PoolManager()

# define a method that will accept a URL with pagination parameter.
def parse(page):
    print("Running for: ", page)
    response = http.request('GET', page)
    html = response.data
    soup = BeautifulSoup(html, 'lxml')
    page_links = soup.findAll('a', attrs={ 'rel': "bookmark" })

    if len(page_links) == 0:
        return False
    else:
        for link in page_links:
            article_links.append(link.get('href'))
        return True

# %%
# initialise feed_url into a variable to make it incremental to be compatible with pagination.
current_page = feed_url

# maintain a counter for pagination
count = 1

# iterate until we get empty results from the page.
while True:
    status = parse(current_page)
    if status == False:
        print("I'm done!")
        break
    count += 1
    current_page = feed_url + "page/" + str(count)
# Out:
# Running for:  http://machinelearningmastery.com/blog/
# Running for:  http://machinelearningmastery.com/blog/page/2
# Running for:  http://machinelearningmastery.com/blog/page/3
# Running for:  http://machinelearningmastery.com/blog/page/4
# Running for:  http://machinelearningmastery.com/blog/page/5
# Running for:  http://machinelearningmastery.com/blog/page/6
# Running for:  http://machinelearningmastery.com/blog/page/7
# Running for:  http://machinelearningmastery.com/blog/page/8
# Running for:  http://machinelearningmastery.com/blog/page/9
# Running for:  http://machinelearningmastery.com/blog/page/10
# Running for:  http://machinelearningmastery.com/blog/page/11
# Running for:  http://machinelearningmastery.com/blog/page/12
# Running for:  http://machinelearningmastery.com/blog/page/13
# Running for:  http://machinelearningmastery.com/blog/page/14
# Running for:  http://machinelearningmastery.com/blog/page/15
# Running for:  http://machinelearningmastery.com/blog/page/16
# Running for:  http://machinelearningmastery.com/blog/page/17
# Running for:  http://machinelearningmastery.com/blog/page/18
# Running for:  http://machinelearningmastery.com/blog/page/19
# Running for:  http://machinelearningmastery.com/blog/page/20
# Running for:  http://machinelearningmastery.com/blog/page/21
# Running for:  http://machinelearningmastery.com/blog/page/22
# Running for:  http://machinelearningmastery.com/blog/page/23
# Running for:  http://machinelearningmastery.com/blog/page/24
# Running for:  http://machinelearningmastery.com/blog/page/25
# Running for:  http://machinelearningmastery.com/blog/page/26
# Running for:  http://machinelearningmastery.com/blog/page/27
# Running for:  http://machinelearningmastery.com/blog/page/28
# Running for:  http://machinelearningmastery.com/blog/page/29
# Running for:  http://machinelearningmastery.com/blog/page/30
# Running for:  http://machinelearningmastery.com/blog/page/31
# Running for:  http://machinelearningmastery.com/blog/page/32
# Running for:  http://machinelearningmastery.com/blog/page/33
# Running for:  http://machinelearningmastery.com/blog/page/34
# Running for:  http://machinelearningmastery.com/blog/page/35
# Running for:  http://machinelearningmastery.com/blog/page/36
# Running for:  http://machinelearningmastery.com/blog/page/37
# Running for:  http://machinelearningmastery.com/blog/page/38
# Running for:  http://machinelearningmastery.com/blog/page/39
# Running for:  http://machinelearningmastery.com/blog/page/40
# Running for:  http://machinelearningmastery.com/blog/page/41
# Running for:  http://machinelearningmastery.com/blog/page/42
# Running for:  http://machinelearningmastery.com/blog/page/43
# Running for:  http://machinelearningmastery.com/blog/page/44
# Running for:  http://machinelearningmastery.com/blog/page/45
# Running for:  http://machinelearningmastery.com/blog/page/46
# Running for:  http://machinelearningmastery.com/blog/page/47
# Running for:  http://machinelearningmastery.com/blog/page/48
# Running for:  http://machinelearningmastery.com/blog/page/49
# Running for:  http://machinelearningmastery.com/blog/page/50
# Running for:  http://machinelearningmastery.com/blog/page/51
# Running for:  http://machinelearningmastery.com/blog/page/52
# Running for:  http://machinelearningmastery.com/blog/page/53
# Running for:  http://machinelearningmastery.com/blog/page/54
# Running for:  http://machinelearningmastery.com/blog/page/55
# Running for:  http://machinelearningmastery.com/blog/page/56
# Running for:  http://machinelearningmastery.com/blog/page/57
# Running for:  http://machinelearningmastery.com/blog/page/58
# Running for:  http://machinelearningmastery.com/blog/page/59
# Running for:  http://machinelearningmastery.com/blog/page/60
# Running for:  http://machinelearningmastery.com/blog/page/61
# Running for:  http://machinelearningmastery.com/blog/page/62
# Running for:  http://machinelearningmastery.com/blog/page/63
# Running for:  http://machinelearningmastery.com/blog/page/64
# Running for:  http://machinelearningmastery.com/blog/page/65
# Running for:  http://machinelearningmastery.com/blog/page/66
# Running for:  http://machinelearningmastery.com/blog/page/67
# Running for:  http://machinelearningmastery.com/blog/page/68
# Running for:  http://machinelearningmastery.com/blog/page/69
# Running for:  http://machinelearningmastery.com/blog/page/70
# I'm done!

# %%
print("Total number of links to crawl: ", len(article_links))
# Out:
# Total number of links to crawl:  684

# %%
### Step 4: Crawl every articles to pull in title, content and URL ###

# machinelearningmastery.com expects User-Agent in the request header.
# else, it throws 403 Forbidden error.
headers = { "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36" }

for link in article_links:
    print("Parsing URL: ", link)

    # open the URL
    current_page = requests.get(link, headers = headers)
    # pass in the html content to BeautifulSoup
    tree = BeautifulSoup(current_page.content, "lxml")
    # parse to find title of the article
    title = tree.body.find('h1', attrs={'class': 'entry-title'}).text
    # parse to find summary of the article
    raw_content = tree.html
    # scrub all the html tags, lowercase all the letters, get rid of \t and \n.
    scrubbed_content = raw_content.text.replace('\t', '').replace('\n', '').lower()
    # add raw data to `raw_json`
    raw_entry = { 'title': title, 'link': link, 'content': raw_content }
    raw_json.append(raw_entry)
    # add scrubbed data to `scrubbed_json`
    scrubbed_entry = { 'title': title, 'link': link, 'content': scrubbed_content }
    scrubbed_json.append(scrubbed_entry)
# Out:
# Parsing URL:  https://machinelearningmastery.com/early-stopping-to-avoid-overtraining-neural-network-models/
# Parsing URL:  https://machinelearningmastery.com/how-to-reduce-overfitting-with-dropout-regularization-in-keras/
# Parsing URL:  https://machinelearningmastery.com/dropout-for-regularizing-deep-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/how-to-reduce-generalization-error-in-deep-neural-networks-with-activity-regularization-in-keras/
# Parsing URL:  https://machinelearningmastery.com/activation-regularization-for-reducing-generalization-error-in-deep-learning-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/how-to-reduce-overfitting-in-deep-neural-networks-with-weight-constraints-in-keras/
# Parsing URL:  https://machinelearningmastery.com/introduction-to-weight-constraints-to-reduce-generalization-error-in-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/how-to-reduce-overfitting-in-deep-learning-with-weight-regularization/
# Parsing URL:  https://machinelearningmastery.com/weight-regularization-to-reduce-overfitting-of-deep-learning-models/
# Parsing URL:  https://machinelearningmastery.com/how-to-grid-search-deep-learning-models-for-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-convolutional-neural-network-models-for-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-multilayer-perceptron-models-for-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/how-to-use-the-timeseriesgenerator-for-time-series-forecasting-in-keras/
# Parsing URL:  https://machinelearningmastery.com/lstm-autoencoders/
# Parsing URL:  https://machinelearningmastery.com/lstm-model-architecture-for-rare-event-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/findings-comparing-classical-and-machine-learning-methods-for-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-deep-learning-models-for-univariate-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/how-to-grid-search-naive-methods-for-univariate-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/how-to-grid-search-sarima-model-hyperparameters-for-time-series-forecasting-in-python/
# Parsing URL:  https://machinelearningmastery.com/how-to-grid-search-triple-exponential-smoothing-for-time-series-forecasting-in-python/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-machine-learning-models-for-multivariate-multi-step-air-pollution-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-autoregressive-forecasting-models-for-multi-step-air-pollution-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-baseline-forecasts-for-multi-site-multivariate-air-pollution-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/how-to-load-visualize-and-explore-a-complex-multivariate-multistep-time-series-forecasting-dataset/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-lstm-models-for-multi-step-time-series-forecasting-of-household-power-consumption/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-convolutional-neural-networks-for-multi-step-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/multi-step-time-series-forecasting-with-machine-learning-models-for-household-electricity-consumption/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-an-autoregression-forecast-model-for-household-electricity-consumption/
# Parsing URL:  https://machinelearningmastery.com/naive-methods-for-forecasting-household-electricity-consumption/
# Parsing URL:  https://machinelearningmastery.com/how-to-load-and-explore-household-electricity-usage-data/
# Parsing URL:  https://machinelearningmastery.com/deep-learning-models-for-human-activity-recognition/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-rnn-models-for-human-activity-recognition-time-series-classification/
# Parsing URL:  https://machinelearningmastery.com/cnn-models-for-human-activity-recognition-time-series-classification/
# Parsing URL:  https://machinelearningmastery.com/evaluate-machine-learning-algorithms-for-human-activity-recognition/
# Parsing URL:  https://machinelearningmastery.com/how-to-model-human-activity-from-smartphone-data/
# Parsing URL:  https://machinelearningmastery.com/spot-check-machine-learning-algorithms-in-python/
# Parsing URL:  https://machinelearningmastery.com/how-to-load-and-explore-a-standard-human-activity-recognition-problem/
# Parsing URL:  https://machinelearningmastery.com/indoor-movement-time-series-classification-with-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-a-probabilistic-forecasting-model-to-predict-air-pollution-days/
# Parsing URL:  https://machinelearningmastery.com/how-to-score-probability-predictions-in-python/
# Parsing URL:  https://machinelearningmastery.com/how-to-get-started-with-deep-learning-for-time-series-forecasting-7-day-mini-course/
# Parsing URL:  https://machinelearningmastery.com/calibrated-classification-model-in-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/
# Parsing URL:  https://machinelearningmastery.com/how-to-predict-room-occupancy-based-on-environmental-factors/
# Parsing URL:  https://machinelearningmastery.com/how-to-predict-whether-eyes-are-open-or-closed-using-brain-waves/
# Parsing URL:  https://machinelearningmastery.com/develop-arch-and-garch-models-for-time-series-forecasting-in-python/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-data-transforms-for-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/exponential-smoothing-for-time-series-forecasting-in-python/
# Parsing URL:  https://machinelearningmastery.com/sarima-for-time-series-forecasting-in-python/
# Parsing URL:  https://machinelearningmastery.com/statistical-hypothesis-tests-in-python-cheat-sheet/
# Parsing URL:  https://machinelearningmastery.com/how-to-reduce-model-variance/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-a-skilful-time-series-forecasting-model/
# Parsing URL:  https://machinelearningmastery.com/taxonomy-of-time-series-forecasting-problems/
# Parsing URL:  https://machinelearningmastery.com/time-series-forecasting-methods-in-python-cheat-sheet/
# Parsing URL:  https://machinelearningmastery.com/statistics-for-machine-learning-mini-course/
# Parsing URL:  https://machinelearningmastery.com/why-initialize-a-neural-network-with-random-weights/
# Parsing URL:  https://machinelearningmastery.com/how-to-code-the-students-t-test-from-scratch-in-python/
# Parsing URL:  https://machinelearningmastery.com/how-to-configure-the-number-of-layers-and-nodes-in-a-neural-network/
# Parsing URL:  https://machinelearningmastery.com/mcnemars-test-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/when-to-use-mlp-cnn-and-rnn-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/
# Parsing URL:  https://machinelearningmastery.com/confounding-variables-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/all-of-statistics-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/statistical-power-and-power-analysis-in-python/
# Parsing URL:  https://machinelearningmastery.com/effect-size-measures-in-python/
# Parsing URL:  https://machinelearningmastery.com/how-to-calculate-nonparametric-rank-correlation-in-python/
# Parsing URL:  https://machinelearningmastery.com/statistics-in-plain-english-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/how-to-generate-random-numbers-in-python/
# Parsing URL:  https://machinelearningmastery.com/statistics-for-evaluating-machine-learning-models/
# Parsing URL:  https://machinelearningmastery.com/relationship-between-applied-statistics-and-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/what-is-statistics/
# Parsing URL:  https://machinelearningmastery.com/statistical-methods-in-an-applied-machine-learning-project/
# Parsing URL:  https://machinelearningmastery.com/controlled-experiments-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/statistical-significance-tests-for-comparing-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/chi-squared-test-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/how-to-calculate-the-5-number-summary-for-your-data-in-python/
# Parsing URL:  https://machinelearningmastery.com/statistical-sampling-and-resampling/
# Parsing URL:  https://machinelearningmastery.com/critical-values-for-statistical-hypothesis-testing/
# Parsing URL:  https://machinelearningmastery.com/statistical-data-distributions/
# Parsing URL:  https://machinelearningmastery.com/data-visualization-methods-in-python/
# Parsing URL:  https://machinelearningmastery.com/estimation-statistics-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/statistical-tolerance-intervals-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/prediction-intervals-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/confidence-intervals-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/a-gentle-introduction-to-the-bootstrap-method/
# Parsing URL:  https://machinelearningmastery.com/k-fold-cross-validation/
# Parsing URL:  https://machinelearningmastery.com/how-to-transform-data-to-fit-the-normal-distribution/
# Parsing URL:  https://machinelearningmastery.com/parametric-statistical-significance-tests-in-python/
# Parsing URL:  https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
# Parsing URL:  https://machinelearningmastery.com/statistical-hypothesis-tests/
# Parsing URL:  https://machinelearningmastery.com/a-gentle-introduction-to-normality-tests-in-python/
# Parsing URL:  https://machinelearningmastery.com/a-gentle-introduction-to-nonparametric-statistics/
# Parsing URL:  https://machinelearningmastery.com/statistics-books-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/a-gentle-introduction-to-the-central-limit-theorem-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/a-gentle-introduction-to-the-law-of-large-numbers-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/a-gentle-introduction-to-calculating-normal-summary-statistics/
# Parsing URL:  https://machinelearningmastery.com/how-to-use-correlation-to-understand-the-relationship-between-variables/
# Parsing URL:  https://machinelearningmastery.com/how-to-use-statistics-to-identify-outliers-in-data/
# Parsing URL:  https://machinelearningmastery.com/introduction-to-random-number-generators-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/how-to-know-if-your-machine-learning-model-has-good-performance/
# Parsing URL:  https://machinelearningmastery.com/the-model-performance-mismatch-problem/
# Parsing URL:  https://machinelearningmastery.com/how-to-get-the-most-from-your-machine-learning-data/
# Parsing URL:  https://machinelearningmastery.com/analytical-vs-numerical-solutions-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-development-environment/
# Parsing URL:  https://machinelearningmastery.com/how-to-make-classification-and-regression-predictions-for-deep-learning-models-in-keras/
# Parsing URL:  https://machinelearningmastery.com/make-predictions-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/working-machine-learning-problem/
# Parsing URL:  https://machinelearningmastery.com/think-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/start-with-gradient-boosting/
# Parsing URL:  https://machinelearningmastery.com/youre-wrong-machine-learning-not-hard/
# Parsing URL:  https://machinelearningmastery.com/basics-mathematical-notation-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/linear-algebra-machine-learning-7-day-mini-course/
# Parsing URL:  https://machinelearningmastery.com/computational-linear-algebra-coders-review/
# Parsing URL:  https://machinelearningmastery.com/linear-algebra-for-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/sparse-matrices-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/broadcasting-with-numpy-arrays/
# Parsing URL:  https://machinelearningmastery.com/examples-of-linear-algebra-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/no-bullshit-guide-to-linear-algebra-review/
# Parsing URL:  https://machinelearningmastery.com/solve-linear-regression-using-linear-algebra/
# Parsing URL:  https://machinelearningmastery.com/calculate-principal-component-analysis-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/introduction-to-expected-value-variance-and-covariance/
# Parsing URL:  https://machinelearningmastery.com/singular-value-decomposition-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/linear-algebra-cheat-sheet-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/resources-for-linear-algebra-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/introduction-to-eigendecomposition-eigenvalues-and-eigenvectors/
# Parsing URL:  https://machinelearningmastery.com/introduction-to-matrix-decompositions-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/introduction-to-tensors-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/matrix-operations-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/introduction-to-types-of-matrices-in-linear-algebra/
# Parsing URL:  https://machinelearningmastery.com/introduction-matrices-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/vector-norms-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-vectors-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-n-dimensional-arrays-python-numpy/
# Parsing URL:  https://machinelearningmastery.com/why-learn-linear-algebra-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-linear-algebra/
# Parsing URL:  https://machinelearningmastery.com/what-is-generalization-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/run-deep-learning-experiments-linux-server/
# Parsing URL:  https://machinelearningmastery.com/standard-multivariate-multi-step-multi-site-time-series-forecasting-problem/
# Parsing URL:  https://machinelearningmastery.com/install-xgboost-python-macos/
# Parsing URL:  https://machinelearningmastery.com/generate-test-datasets-python-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/develop-n-gram-multichannel-convolutional-neural-network-sentiment-analysis/
# Parsing URL:  https://machinelearningmastery.com/develop-neural-machine-translation-system-keras/
# Parsing URL:  https://machinelearningmastery.com/prepare-french-english-dataset-machine-translation/
# Parsing URL:  https://machinelearningmastery.com/beam-search-decoder-natural-language-processing/
# Parsing URL:  https://machinelearningmastery.com/configure-encoder-decoder-model-neural-machine-translation/
# Parsing URL:  https://machinelearningmastery.com/encoder-decoder-recurrent-neural-network-models-neural-machine-translation/
# Parsing URL:  https://machinelearningmastery.com/introduction-neural-machine-translation/
# Parsing URL:  https://machinelearningmastery.com/caption-generation-inject-merge-architectures-encoder-decoder-model/
# Parsing URL:  https://machinelearningmastery.com/applied-machine-learning-as-a-search-problem/
# Parsing URL:  https://machinelearningmastery.com/applied-machine-learning-is-hard/
# Parsing URL:  https://machinelearningmastery.com/transfer-learning-for-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/exploding-gradients-in-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-concept-drift-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/visualize-deep-learning-neural-network-model-keras/
# Parsing URL:  https://machinelearningmastery.com/classification-versus-regression-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/encoder-decoder-models-text-summarization-keras/
# Parsing URL:  https://machinelearningmastery.com/teacher-forcing-for-recurrent-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/prepare-news-articles-text-summarization/
# Parsing URL:  https://machinelearningmastery.com/encoder-decoder-deep-learning-models-text-summarization/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-text-summarization/
# Parsing URL:  https://machinelearningmastery.com/develop-a-deep-learning-caption-generation-model-in-python/
# Parsing URL:  https://machinelearningmastery.com/develop-a-caption-generation-model-in-keras/
# Parsing URL:  https://machinelearningmastery.com/deep-learning-caption-generation-models/
# Parsing URL:  https://machinelearningmastery.com/calculate-bleu-score-for-text-python/
# Parsing URL:  https://machinelearningmastery.com/prepare-univariate-time-series-data-long-short-term-memory-networks/
# Parsing URL:  https://machinelearningmastery.com/prepare-photo-caption-dataset-training-deep-learning-model/
# Parsing URL:  https://machinelearningmastery.com/how-to-caption-photos-with-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/how-to-develop-a-word-level-neural-language-model-in-keras/
# Parsing URL:  https://machinelearningmastery.com/use-pre-trained-vgg-model-classify-objects-photographs/
# Parsing URL:  https://machinelearningmastery.com/crash-course-deep-learning-natural-language-processing/
# Parsing URL:  https://machinelearningmastery.com/develop-character-based-neural-language-model-keras/
# Parsing URL:  https://machinelearningmastery.com/develop-word-based-neural-language-models-python-keras/
# Parsing URL:  https://machinelearningmastery.com/develop-encoder-decoder-model-sequence-sequence-prediction-keras/
# Parsing URL:  https://machinelearningmastery.com/statistical-language-modeling-and-neural-language-models/
# Parsing URL:  https://machinelearningmastery.com/global-attention-for-encoder-decoder-recurrent-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/develop-word-embedding-model-predicting-movie-review-sentiment/
# Parsing URL:  https://machinelearningmastery.com/keras-functional-api-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/define-encoder-decoder-sequence-sequence-model-neural-machine-translation-keras/
# Parsing URL:  https://machinelearningmastery.com/index-slice-reshape-numpy-arrays-machine-learning-python/
# Parsing URL:  https://machinelearningmastery.com/return-sequences-and-return-states-for-lstms-in-keras/
# Parsing URL:  https://machinelearningmastery.com/best-practices-document-classification-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/deep-learning-bag-of-words-model-sentiment-analysis/
# Parsing URL:  https://machinelearningmastery.com/implementation-patterns-encoder-decoder-rnn-architecture-attention/
# Parsing URL:  https://machinelearningmastery.com/clean-text-machine-learning-python/
# Parsing URL:  https://machinelearningmastery.com/encoder-decoder-attention-sequence-to-sequence-prediction-keras/
# Parsing URL:  https://machinelearningmastery.com/prepare-movie-review-data-sentiment-analysis/
# Parsing URL:  https://machinelearningmastery.com/how-does-attention-work-in-encoder-decoder-recurrent-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/what-are-word-embeddings/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-bag-words-model/
# Parsing URL:  https://machinelearningmastery.com/develop-word-embeddings-python-gensim/
# Parsing URL:  https://machinelearningmastery.com/use-word-embedding-layers-deep-learning-keras/
# Parsing URL:  https://machinelearningmastery.com/prepare-text-data-deep-learning-keras/
# Parsing URL:  https://machinelearningmastery.com/prepare-text-data-machine-learning-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/datasets-natural-language-processing/
# Parsing URL:  https://machinelearningmastery.com/promise-deep-learning-natural-language-processing/
# Parsing URL:  https://machinelearningmastery.com/natural-language-processing/
# Parsing URL:  https://machinelearningmastery.com/applications-of-deep-learning-for-natural-language-processing/
# Parsing URL:  https://machinelearningmastery.com/transduction-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/primer-neural-network-models-natural-language-processing/
# Parsing URL:  https://machinelearningmastery.com/oxford-course-deep-learning-natural-language-processing/
# Parsing URL:  https://machinelearningmastery.com/stanford-deep-learning-for-natural-language-processing-course/
# Parsing URL:  https://machinelearningmastery.com/books-on-natural-language-processing/
# Parsing URL:  https://machinelearningmastery.com/rnn-unrolling/
# Parsing URL:  https://machinelearningmastery.com/sequence-prediction/
# Parsing URL:  https://machinelearningmastery.com/diagnose-overfitting-underfitting-lstm-models/
# Parsing URL:  https://machinelearningmastery.com/reshape-input-data-long-short-term-memory-networks-keras/
# Parsing URL:  https://machinelearningmastery.com/make-predictions-long-short-term-memory-models-keras/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-generative-long-short-term-memory-networks/
# Parsing URL:  https://machinelearningmastery.com/encoder-decoder-long-short-term-memory-networks/
# Parsing URL:  https://machinelearningmastery.com/cnn-long-short-term-memory-networks/
# Parsing URL:  https://machinelearningmastery.com/stacked-long-short-term-memory-networks/
# Parsing URL:  https://machinelearningmastery.com/long-short-term-memory-recurrent-neural-networks-mini-course/
# Parsing URL:  https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/
# Parsing URL:  https://machinelearningmastery.com/get-the-most-out-of-lstms/
# Parsing URL:  https://machinelearningmastery.com/custom-metrics-deep-learning-keras-python/
# Parsing URL:  https://machinelearningmastery.com/command-line-recipes-deep-learning-amazon-web-services/
# Parsing URL:  https://machinelearningmastery.com/plan-run-machine-learning-experiments-systematically/
# Parsing URL:  https://machinelearningmastery.com/get-help-with-keras/
# Parsing URL:  https://machinelearningmastery.com/get-good-results-fast-deep-learning-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/difference-between-a-parameter-and-a-hyperparameter/
# Parsing URL:  https://machinelearningmastery.com/much-training-data-required-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-mini-batch-gradient-descent-configure-batch-size/
# Parsing URL:  https://machinelearningmastery.com/sequence-prediction-problems-learning-lstm-recurrent-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/models-sequence-prediction-recurrent-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/difference-test-validation-datasets/
# Parsing URL:  https://machinelearningmastery.com/how-to-one-hot-encode-sequence-data-in-python/
# Parsing URL:  https://machinelearningmastery.com/remove-trends-seasonality-difference-transform-python/
# Parsing URL:  https://machinelearningmastery.com/how-to-scale-data-for-long-short-term-memory-networks-in-python/
# Parsing URL:  https://machinelearningmastery.com/recurrent-neural-network-algorithms-for-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/attention-long-short-term-memory-recurrent-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/truncated-backpropagation-through-time-in-keras/
# Parsing URL:  https://machinelearningmastery.com/handle-long-sequences-long-short-term-memory-recurrent-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-backpropagation-time/
# Parsing URL:  https://machinelearningmastery.com/handle-missing-timesteps-sequence-prediction-problems-python/
# Parsing URL:  https://machinelearningmastery.com/data-preparation-variable-length-input-sequences-sequence-prediction/
# Parsing URL:  https://machinelearningmastery.com/develop-bidirectional-lstm-sequence-classification-python-keras/
# Parsing URL:  https://machinelearningmastery.com/reproducible-results-neural-networks-keras/
# Parsing URL:  https://machinelearningmastery.com/how-to-use-an-encoder-decoder-lstm-to-echo-sequences-of-random-integers/
# Parsing URL:  https://machinelearningmastery.com/learn-echo-random-integers-long-short-term-memory-recurrent-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/5-step-life-cycle-long-short-term-memory-models-keras/
# Parsing URL:  https://machinelearningmastery.com/calculate-bootstrap-confidence-intervals-machine-learning-results-python/
# Parsing URL:  https://machinelearningmastery.com/report-classifier-performance-confidence-intervals/
# Parsing URL:  https://machinelearningmastery.com/evaluate-skill-deep-learning-models/
# Parsing URL:  https://machinelearningmastery.com/large-data-files-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/suitability-long-short-term-memory-networks-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-long-short-term-memory-networks-experts/
# Parsing URL:  https://machinelearningmastery.com/promise-recurrent-neural-networks-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/learn-add-numbers-seq2seq-recurrent-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/timedistributed-layer-for-long-short-term-memory-networks-in-python/
# Parsing URL:  https://machinelearningmastery.com/use-different-batch-sizes-training-predicting-python-keras/
# Parsing URL:  https://machinelearningmastery.com/memory-in-a-long-short-term-memory-network/
# Parsing URL:  https://machinelearningmastery.com/multi-step-time-series-forecasting-long-short-term-memory-networks-python/
# Parsing URL:  https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/
# Parsing URL:  https://machinelearningmastery.com/use-weight-regularization-lstm-networks-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/use-statistical-significance-tests-interpret-machine-learning-results/
# Parsing URL:  https://machinelearningmastery.com/estimate-number-experiment-repeats-stochastic-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/use-dropout-lstm-networks-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/exploratory-configuration-multilayer-perceptron-network-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/instability-online-learning-stateful-lstm-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/stateful-stateless-lstm-time-series-forecasting-python/
# Parsing URL:  https://machinelearningmastery.com/use-features-lstm-networks-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/use-timesteps-lstm-networks-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/update-lstm-networks-training-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/tune-lstm-hyperparameters-keras-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/seed-state-lstms-time-series-forecasting-python/
# Parsing URL:  https://machinelearningmastery.com/time-series-forecasting-long-short-term-memory-network-python/
# Parsing URL:  https://machinelearningmastery.com/seasonal-persistence-forecasting-python/
# Parsing URL:  https://machinelearningmastery.com/tune-arima-parameters-python/
# Parsing URL:  https://machinelearningmastery.com/simple-time-series-forecasting-models/
# Parsing URL:  https://machinelearningmastery.com/feature-selection-time-series-forecasting-python/
# Parsing URL:  https://machinelearningmastery.com/sensitivity-analysis-history-size-forecast-skill-arima-python/
# Parsing URL:  https://machinelearningmastery.com/make-sample-forecasts-arima-python/
# Parsing URL:  https://machinelearningmastery.com/time-series-forecasting-python-mini-course/
# Parsing URL:  https://machinelearningmastery.com/handle-missing-data-python/
# Parsing URL:  https://machinelearningmastery.com/train-final-machine-learning-model/
# Parsing URL:  https://machinelearningmastery.com/install-python-3-environment-mac-os-x-machine-learning-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/setup-python-environment-machine-learning-deep-learning-anaconda/
# Parsing URL:  https://machinelearningmastery.com/get-started-with-kaggle/
# Parsing URL:  https://machinelearningmastery.com/multi-step-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/white-noise-time-series-python/
# Parsing URL:  https://machinelearningmastery.com/python-environment-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/challenging-machine-learning-time-series-forecasting-problems/
# Parsing URL:  https://machinelearningmastery.com/linux-virtual-machine-machine-learning-development-python-3/
# Parsing URL:  https://machinelearningmastery.com/save-arima-time-series-forecasting-model-python/
# Parsing URL:  https://machinelearningmastery.com/difference-time-series-dataset-python/
# Parsing URL:  https://machinelearningmastery.com/time-series-forecast-study-python-monthly-sales-french-champagne/
# Parsing URL:  https://machinelearningmastery.com/student-got-machine-learning-internship-job-data-science-team/
# Parsing URL:  https://machinelearningmastery.com/time-series-forecast-study-python-annual-water-usage-baltimore/
# Parsing URL:  https://machinelearningmastery.com/time-series-forecast-case-study-python-monthly-armed-robberies-boston/
# Parsing URL:  https://machinelearningmastery.com/time-series-forecast-uncertainty-using-confidence-intervals-python/
# Parsing URL:  https://machinelearningmastery.com/make-manual-predictions-arima-models-python/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-autocorrelation-partial-autocorrelation/
# Parsing URL:  https://machinelearningmastery.com/work-time-series-forecast-project/
# Parsing URL:  https://machinelearningmastery.com/time-series-forecasting-performance-measures-with-python/
# Parsing URL:  https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/
# Parsing URL:  https://machinelearningmastery.com/make-predictions-time-series-forecasting-python/
# Parsing URL:  https://machinelearningmastery.com/power-transform-time-series-forecast-data-python/
# Parsing URL:  https://machinelearningmastery.com/reframe-time-series-forecasting-problem/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-random-walk-times-series-forecasting-python/
# Parsing URL:  https://machinelearningmastery.com/grid-search-arima-hyperparameters-with-python/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-books/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-box-jenkins-method-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/model-residual-errors-correct-time-series-forecasts-python/
# Parsing URL:  https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/
# Parsing URL:  https://machinelearningmastery.com/visualize-time-series-residual-forecast-errors-with-python/
# Parsing URL:  https://machinelearningmastery.com/time-series-data-visualization-with-python/
# Parsing URL:  https://machinelearningmastery.com/autoregression-models-time-series-forecasting-python/
# Parsing URL:  https://machinelearningmastery.com/time-series-data-stationary-python/
# Parsing URL:  https://machinelearningmastery.com/moving-average-smoothing-for-time-series-forecasting-python/
# Parsing URL:  https://machinelearningmastery.com/persistence-time-series-forecasting-with-python/
# Parsing URL:  https://machinelearningmastery.com/time-series-seasonality-with-python/
# Parsing URL:  https://machinelearningmastery.com/time-series-trends-in-python/
# Parsing URL:  https://machinelearningmastery.com/backtest-machine-learning-models-time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/resample-interpolate-time-series-data-python/
# Parsing URL:  https://machinelearningmastery.com/basic-feature-engineering-time-series-data-python/
# Parsing URL:  https://machinelearningmastery.com/normalize-standardize-time-series-data-python/
# Parsing URL:  https://machinelearningmastery.com/load-explore-time-series-data-python/
# Parsing URL:  https://machinelearningmastery.com/how-to-go-from-working-in-a-bank-to-hired-as-senior-data-scientist-at-target/
# Parsing URL:  https://machinelearningmastery.com/time-series-forecasting-supervised-learning/
# Parsing URL:  https://machinelearningmastery.com/time-series-forecasting/
# Parsing URL:  https://machinelearningmastery.com/time-series-datasets-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-podcasts/
# Parsing URL:  https://machinelearningmastery.com/standard-machine-learning-datasets/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-performance-improvement-cheat-sheet/
# Parsing URL:  https://machinelearningmastery.com/books-on-time-series-forecasting-with-r/
# Parsing URL:  https://machinelearningmastery.com/confusion-matrix-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/implementing-stacking-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/implement-random-forest-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/implement-bagging-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/implement-decision-tree-algorithm-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/implement-backpropagation-algorithm-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/implement-learning-vector-quantization-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/implement-perceptron-algorithm-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/python-growing-platform-applied-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/implement-logistic-regression-stochastic-gradient-descent-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/implement-linear-regression-stochastic-gradient-descent-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/implement-simple-linear-regression-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/create-algorithm-test-harness-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/implement-baseline-machine-learning-algorithms-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/implement-machine-learning-algorithm-performance-metrics-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/implement-resampling-methods-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/scale-machine-learning-data-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/load-machine-learning-data-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-mastery-method/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-year/
# Parsing URL:  https://machinelearningmastery.com/dont-implement-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/beginners-get-it-wrong/
# Parsing URL:  https://machinelearningmastery.com/deploy-machine-learning-model-to-production/
# Parsing URL:  https://machinelearningmastery.com/randomness-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/python-machine-learning-mini-course/
# Parsing URL:  https://machinelearningmastery.com/xgboost-python-mini-course/
# Parsing URL:  https://machinelearningmastery.com/improve-deep-learning-performance/
# Parsing URL:  https://machinelearningmastery.com/stochastic-gradient-boosting-xgboost-scikit-learn-python/
# Parsing URL:  https://machinelearningmastery.com/tune-learning-rate-for-gradient-boosting-with-xgboost-in-python/
# Parsing URL:  https://machinelearningmastery.com/deep-learning-for-developers/
# Parsing URL:  https://machinelearningmastery.com/train-xgboost-models-cloud-amazon-web-services/
# Parsing URL:  https://machinelearningmastery.com/configure-gradient-boosting-algorithm/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-gradient-boosting-algorithm-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/tune-number-size-decision-trees-xgboost-python/
# Parsing URL:  https://machinelearningmastery.com/best-tune-multithreading-support-xgboost-python/
# Parsing URL:  https://machinelearningmastery.com/avoid-overfitting-by-early-stopping-with-xgboost-in-python/
# Parsing URL:  https://machinelearningmastery.com/feature-importance-and-feature-selection-with-xgboost-in-python/
# Parsing URL:  https://machinelearningmastery.com/visualize-gradient-boosting-decision-trees-xgboost-python/
# Parsing URL:  https://machinelearningmastery.com/evaluate-gradient-boosting-models-xgboost-python/
# Parsing URL:  https://machinelearningmastery.com/save-gradient-boosting-models-xgboost-python/
# Parsing URL:  https://machinelearningmastery.com/data-preparation-gradient-boosting-xgboost-python/
# Parsing URL:  https://machinelearningmastery.com/develop-first-xgboost-model-python-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-xgboost-applied-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/what-is-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/applied-machine-learning-weka-mini-course/
# Parsing URL:  https://machinelearningmastery.com/help-with-weka/
# Parsing URL:  https://machinelearningmastery.com/5-step-life-cycle-neural-network-models-keras/
# Parsing URL:  https://machinelearningmastery.com/regression-machine-learning-tutorial-weka/
# Parsing URL:  https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/
# Parsing URL:  https://machinelearningmastery.com/binary-classification-tutorial-weka/
# Parsing URL:  https://machinelearningmastery.com/multi-class-classification-tutorial-weka/
# Parsing URL:  https://machinelearningmastery.com/text-generation-lstm-recurrent-neural-networks-python-keras/
# Parsing URL:  https://machinelearningmastery.com/save-machine-learning-model-make-predictions-weka/
# Parsing URL:  https://machinelearningmastery.com/data-leakage-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/tune-machine-learning-algorithms-weka/
# Parsing URL:  https://machinelearningmastery.com/compare-performance-machine-learning-algorithms-weka/
# Parsing URL:  https://machinelearningmastery.com/understanding-stateful-lstm-recurrent-neural-networks-python-keras/
# Parsing URL:  https://machinelearningmastery.com/use-ensemble-machine-learning-algorithms-weka/
# Parsing URL:  https://machinelearningmastery.com/sequence-classification-lstm-recurrent-neural-networks-python-keras/
# Parsing URL:  https://machinelearningmastery.com/use-classification-machine-learning-algorithms-weka/
# Parsing URL:  https://machinelearningmastery.com/use-regression-machine-learning-algorithms-weka/
# Parsing URL:  https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
# Parsing URL:  https://machinelearningmastery.com/estimate-baseline-performance-machine-learning-models-weka/
# Parsing URL:  https://machinelearningmastery.com/time-series-prediction-with-deep-learning-in-python-with-keras/
# Parsing URL:  https://machinelearningmastery.com/estimate-performance-machine-learning-algorithms-weka/
# Parsing URL:  https://machinelearningmastery.com/use-machine-learning-algorithms-weka/
# Parsing URL:  https://machinelearningmastery.com/inspirational-applications-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/perform-feature-selection-machine-learning-data-weka/
# Parsing URL:  https://machinelearningmastery.com/deep-learning-courses/
# Parsing URL:  https://machinelearningmastery.com/how-to-handle-missing-values-in-machine-learning-data-with-weka/
# Parsing URL:  https://machinelearningmastery.com/transform-machine-learning-data-weka/
# Parsing URL:  https://machinelearningmastery.com/crash-course-recurrent-neural-networks-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/applied-deep-learning-in-python-mini-course/
# Parsing URL:  https://machinelearningmastery.com/normalize-standardize-machine-learning-data-weka/
# Parsing URL:  https://machinelearningmastery.com/predict-sentiment-movie-reviews-using-deep-learning/
# Parsing URL:  https://machinelearningmastery.com/object-recognition-convolutional-neural-networks-keras-deep-learning-library/
# Parsing URL:  https://machinelearningmastery.com/better-understand-machine-learning-data-weka/
# Parsing URL:  https://machinelearningmastery.com/image-augmentation-deep-learning-keras/
# Parsing URL:  https://machinelearningmastery.com/standard-machine-learning-datasets-used-practice-weka/
# Parsing URL:  https://machinelearningmastery.com/handwritten-digit-recognition-using-convolutional-neural-networks-python-keras/
# Parsing URL:  https://machinelearningmastery.com/crash-course-convolutional-neural-networks/
# Parsing URL:  https://machinelearningmastery.com/load-csv-machine-learning-data-weka/
# Parsing URL:  https://machinelearningmastery.com/using-learning-rate-schedules-deep-learning-models-python-keras/
# Parsing URL:  https://machinelearningmastery.com/tour-weka-machine-learning-workbench/
# Parsing URL:  https://machinelearningmastery.com/dropout-regularization-deep-learning-models-keras/
# Parsing URL:  https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
# Parsing URL:  https://machinelearningmastery.com/download-install-weka-machine-learning-workbench/
# Parsing URL:  https://machinelearningmastery.com/check-point-deep-learning-models-keras/
# Parsing URL:  https://machinelearningmastery.com/applied-machine-learning-with-weka/
# Parsing URL:  https://machinelearningmastery.com/save-load-keras-deep-learning-models/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-in-python-step-by-step/
# Parsing URL:  https://machinelearningmastery.com/regression-tutorial-keras-deep-learning-library-python/
# Parsing URL:  https://machinelearningmastery.com/save-load-machine-learning-models-python-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/binary-classification-tutorial-with-the-keras-deep-learning-library/
# Parsing URL:  https://machinelearningmastery.com/automate-machine-learning-workflows-pipelines-python-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/ensemble-machine-learning-algorithms-python-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/multi-class-classification-tutorial-keras-deep-learning-library/
# Parsing URL:  https://machinelearningmastery.com/compare-machine-learning-algorithms-python-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/use-keras-deep-learning-models-scikit-learn-python/
# Parsing URL:  https://machinelearningmastery.com/spot-check-regression-machine-learning-algorithms-python-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/spot-check-classification-machine-learning-algorithms-python-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/evaluate-performance-deep-learning-models-keras/
# Parsing URL:  https://machinelearningmastery.com/metrics-evaluate-machine-learning-algorithms-python/
# Parsing URL:  https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/
# Parsing URL:  https://machinelearningmastery.com/evaluate-performance-machine-learning-algorithms-python-using-resampling/
# Parsing URL:  https://machinelearningmastery.com/feature-selection-machine-learning-python/
# Parsing URL:  https://machinelearningmastery.com/build-multi-layer-perceptron-neural-network-models-keras/
# Parsing URL:  https://machinelearningmastery.com/prepare-data-machine-learning-python-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/neural-networks-crash-course/
# Parsing URL:  https://machinelearningmastery.com/visualize-machine-learning-data-python-pandas/
# Parsing URL:  https://machinelearningmastery.com/understand-machine-learning-data-descriptive-statistics-python/
# Parsing URL:  https://machinelearningmastery.com/develop-evaluate-large-deep-learning-models-keras-amazon-web-services/
# Parsing URL:  https://machinelearningmastery.com/load-machine-learning-data-python/
# Parsing URL:  https://machinelearningmastery.com/introduction-python-deep-learning-library-keras/
# Parsing URL:  https://machinelearningmastery.com/scikit-learn-cookbook-book-review/
# Parsing URL:  https://machinelearningmastery.com/introduction-machine-learning-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/introduction-python-deep-learning-library-tensorflow/
# Parsing URL:  https://machinelearningmastery.com/crash-course-python-machine-learning-developers/
# Parsing URL:  https://machinelearningmastery.com/introduction-python-deep-learning-library-theano/
# Parsing URL:  https://machinelearningmastery.com/python-ecosystem-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-algorithms-mini-course/
# Parsing URL:  https://machinelearningmastery.com/question-to-understand-any-machine-learning-algorithm/
# Parsing URL:  https://machinelearningmastery.com/boosting-and-adaboost-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/bagging-and-random-forest-ensemble-algorithms-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/support-vector-machines-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/learning-vector-quantization-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/k-nearest-neighbors-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/popular-deep-learning-libraries/
# Parsing URL:  https://machinelearningmastery.com/naive-bayes-tutorial-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/naive-bayes-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/classification-and-regression-trees-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/deep-learning-books/
# Parsing URL:  https://machinelearningmastery.com/linear-discriminant-analysis-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/logistic-regression-tutorial-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/logistic-regression-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/linear-regression-tutorial-using-gradient-descent-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/simple-linear-regression-tutorial-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/linear-regression-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/gradient-descent-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/overfitting-and-underfitting-with-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/gentle-introduction-to-the-bias-variance-trade-off-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/supervised-and-unsupervised-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/parametric-and-nonparametric-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/how-machine-learning-algorithms-work/
# Parsing URL:  https://machinelearningmastery.com/data-terminology-in-machine-learning/
# ...
# Parsing URL:  https://machinelearningmastery.com/machine-learning-model-running/
# Parsing URL:  https://machinelearningmastery.com/common-pitfalls-machine-learning-projects/
# Parsing URL:  https://machinelearningmastery.com/linear-algebra-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-statistical-causal-methods/
# Parsing URL:  https://machinelearningmastery.com/how-to-work-through-a-problem-like-a-data-scientist/
# Parsing URL:  https://machinelearningmastery.com/get-started-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/practical-machine-learning-books-for-the-holidays/
# Parsing URL:  https://machinelearningmastery.com/use-random-forest-testing-179-classifiers-121-datasets/
# Parsing URL:  https://machinelearningmastery.com/better-naive-bayes/
# Parsing URL:  https://machinelearningmastery.com/naive-bayes-classifier-scratch-python/
# Parsing URL:  https://machinelearningmastery.com/lessons-learned-building-machine-learning-systems/
# Parsing URL:  https://machinelearningmastery.com/get-dream-job-machine-learning-delivering-results/
# Parsing URL:  https://machinelearningmastery.com/assessing-comparing-classifier-performance-roc-curves-2/
# Parsing URL:  https://machinelearningmastery.com/data-science-skills-simple-method-can-use-evaluate-use-results-build-amazing-data-science-teams/
# Parsing URL:  https://machinelearningmastery.com/understand-problem-get-better-results-using-exploratory-data-analysis/
# Parsing URL:  https://machinelearningmastery.com/data-management-matters-and-why-you-need-to-take-it-seriously/
# Parsing URL:  https://machinelearningmastery.com/become-data-scientist/
# Parsing URL:  https://machinelearningmastery.com/crash-course-statistics-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/arent-results-good-thought-youre-probably-overfitting/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-qa-concept-drift-better-results-and-learning-faster/
# Parsing URL:  https://machinelearningmastery.com/hello-world-of-applied-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/how-to-get-baseline-results-and-why-they-matter/
# Parsing URL:  https://machinelearningmastery.com/create-lists-of-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/dont-start-with-open-source-code-when-implementing-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/how-to-investigate-machine-learning-algorithm-behavior/
# Parsing URL:  https://machinelearningmastery.com/how-to-research-a-machine-learning-algorithm/
# Parsing URL:  https://machinelearningmastery.com/model-selection-tips-from-competitive-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/how-to-study-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/5-machine-learning-areas-you-should-be-cultivating/
# Parsing URL:  https://machinelearningmastery.com/16-options-to-get-started-and-make-progress-in-machine-learning-and-data-science/
# Parsing URL:  https://machinelearningmastery.com/building-a-production-machine-learning-infrastructure/
# Parsing URL:  https://machinelearningmastery.com/an-introduction-to-feature-selection/
# Parsing URL:  https://machinelearningmastery.com/discover-the-methodology-and-mindset-of-a-kaggle-master-an-interview-with-diogo-ferreira/
# Parsing URL:  https://machinelearningmastery.com/how-to-build-an-intuition-for-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/a-data-driven-approach-to-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/discover-feature-engineering-how-to-engineer-features-and-how-to-get-good-at-it/
# Parsing URL:  https://machinelearningmastery.com/compare-models-and-select-the-best-using-the-caret-r-package/
# Parsing URL:  https://machinelearningmastery.com/feature-selection-with-the-caret-r-package/
# Parsing URL:  https://machinelearningmastery.com/tuning-machine-learning-models-using-the-caret-r-package/
# Parsing URL:  https://machinelearningmastery.com/data-visualization-with-the-caret-r-package/
# Parsing URL:  https://machinelearningmastery.com/caret-r-package-for-applied-predictive-modeling/
# Parsing URL:  https://machinelearningmastery.com/tutorial-to-implement-k-nearest-neighbors-in-python-from-scratch/
# Parsing URL:  https://machinelearningmastery.com/benefits-of-implementing-machine-learning-algorithms-from-scratch/
# Parsing URL:  https://machinelearningmastery.com/review-of-applied-predictive-modeling/
# Parsing URL:  https://machinelearningmastery.com/how-to-get-started-with-machine-learning-algorithms-in-r/
# Parsing URL:  https://machinelearningmastery.com/how-to-estimate-model-accuracy-in-r-using-the-caret-package/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-newsletters/
# Parsing URL:  https://machinelearningmastery.com/convex-optimization-in-r/
# Parsing URL:  https://machinelearningmastery.com/non-linear-classification-in-r-with-decision-trees/
# Parsing URL:  https://machinelearningmastery.com/what-is-r/
# Parsing URL:  https://machinelearningmastery.com/5-benefits-of-competitive-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/master-kaggle-by-competing-consistently/
# Parsing URL:  https://machinelearningmastery.com/going-beyond-predictions/
# Parsing URL:  https://machinelearningmastery.com/how-to-kick-ass-in-competitive-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/how-to-get-better-at-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/non-linear-classification-in-r/
# Parsing URL:  https://machinelearningmastery.com/linear-classification-in-r/
# Parsing URL:  https://machinelearningmastery.com/clever-application-of-a-predictive-model/
# Parsing URL:  https://machinelearningmastery.com/improve-model-accuracy-with-data-pre-processing/
# Parsing URL:  https://machinelearningmastery.com/model-prediction-versus-interpretation-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/non-linear-regression-in-r-with-decision-trees/
# Parsing URL:  https://machinelearningmastery.com/non-linear-regression-in-r/
# Parsing URL:  https://machinelearningmastery.com/penalized-regression-in-r/
# Parsing URL:  https://machinelearningmastery.com/linear-regression-in-r/
# Parsing URL:  https://machinelearningmastery.com/applied-machine-learning-lessons-from-a-case-study-of-passenger-survival-prediction/
# Parsing URL:  https://machinelearningmastery.com/java-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/how-to-tune-algorithm-parameters-with-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/feature-selection-in-python-with-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/rescaling-data-for-machine-learning-in-python-with-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/how-to-load-data-in-python-with-scikit-learn/
# Parsing URL:  https://machinelearningmastery.com/data-science-screencasts-a-data-origami-review/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-is-kaggle-competitions/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-communities/
# Parsing URL:  https://machinelearningmastery.com/books-for-machine-learning-with-r/
# Parsing URL:  https://machinelearningmastery.com/practical-advice-for-getting-started-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/quick-and-dirty-data-analysis-with-pandas/
# Parsing URL:  https://machinelearningmastery.com/prepare-data-for-machine-learning-in-python-with-pandas/
# Parsing URL:  https://machinelearningmastery.com/get-your-hands-dirty-with-scikit-learn-now/
# Parsing URL:  https://machinelearningmastery.com/the-best-machine-learning-algorithm/
# Parsing URL:  https://machinelearningmastery.com/computer-hardware-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/how-i-got-started-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-for-money/
# Parsing URL:  https://machinelearningmastery.com/work-on-machine-learning-problems-that-matter-to-you/
# Parsing URL:  https://machinelearningmastery.com/build-a-machine-learning-portfolio/
# Parsing URL:  https://machinelearningmastery.com/what-is-holding-you-back-from-your-machine-learning-goals/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-roadmap-your-self-study-guide-to-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/data-cleaning-turn-messy-data-into-tidy-data/
# Parsing URL:  https://machinelearningmastery.com/the-data-analytics-handbook-researchers-and-academics-review/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-with-quantum-computers/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-that-matters/
# Parsing URL:  https://machinelearningmastery.com/bootstrapping-machine-learning-book-review/
# Parsing URL:  https://machinelearningmastery.com/lessons-for-machine-learning-from-econometrics/
# Parsing URL:  https://machinelearningmastery.com/using-opencv-python-and-template-matching-to-play-wheres-waldo/
# Parsing URL:  https://machinelearningmastery.com/the-data-analytics-handbook-ceos-and-managers/
# Parsing URL:  https://machinelearningmastery.com/how-to-layout-and-manage-your-machine-learning-project/
# Parsing URL:  https://machinelearningmastery.com/best-programming-language-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/the-seductive-trap-of-black-box-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/ipython-from-the-shell-to-a-book-with-a-single-tool-with-fernando-perez/
# Parsing URL:  https://machinelearningmastery.com/how-to-get-started-with-machine-learning-in-python/
# Parsing URL:  https://machinelearningmastery.com/the-data-analytics-handbook-data-analysts-and-data-scientists/
# Parsing URL:  https://machinelearningmastery.com/bootstrapping-machine-learning-an-upcoming-book-on-prediction-apis/
# Parsing URL:  https://machinelearningmastery.com/a-gentle-introduction-to-scikit-learn-a-python-machine-learning-library/
# Parsing URL:  https://machinelearningmastery.com/python-machine-learning-books/
# Parsing URL:  https://machinelearningmastery.com/case-study-predicting-the-onset-of-diabetes-within-five-years-part-3-of-3/
# Parsing URL:  https://machinelearningmastery.com/introduction-to-bayesian-networks-with-jhonatan-de-souza-oliveira/
# Parsing URL:  https://machinelearningmastery.com/bigml-tutorial-develop-your-first-decision-tree-and-make-predictions/
# Parsing URL:  https://machinelearningmastery.com/case-study-predicting-the-onset-of-diabetes-within-five-years-part-2-of-3/
# Parsing URL:  https://machinelearningmastery.com/project-spotlight-face-recognition-with-shashank-singh/
# Parsing URL:  https://machinelearningmastery.com/bigml-review-discover-the-clever-features-in-this-machine-learning-as-a-service-platform/
# Parsing URL:  https://machinelearningmastery.com/case-study-predicting-the-onset-of-diabetes-within-five-years-part-1-of-3/
# Parsing URL:  https://machinelearningmastery.com/5-steps-to-thinking-like-a-designer-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-tips-from-a-world-class-practitioner-phil-brierley/
# Parsing URL:  https://machinelearningmastery.com/classification-accuracy-is-not-enough-more-performance-measures-you-can-use/
# Parsing URL:  https://machinelearningmastery.com/project-spotlight-with-artem-yankov/
# Parsing URL:  https://machinelearningmastery.com/market-basket-analysis-with-association-rule-learning/
# Parsing URL:  https://machinelearningmastery.com/project-spotlight-stack-exchange-clustering-using-mahout-with-konstantin-slisenko/
# Parsing URL:  https://machinelearningmastery.com/feature-selection-to-improve-accuracy-and-decrease-training-time/
# Parsing URL:  https://machinelearningmastery.com/biggest-mistake-i-made-when-starting-machine-learning-and-how-to-avoid-it/
# Parsing URL:  https://machinelearningmastery.com/template-for-working-through-machine-learning-problems-in-weka/
# Parsing URL:  https://machinelearningmastery.com/a-simple-intuition-for-overfitting/
# Parsing URL:  https://machinelearningmastery.com/4-steps-to-get-started-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/improve-machine-learning-results-with-boosting-bagging-and-blending-ensemble-methods-in-weka/
# Parsing URL:  https://machinelearningmastery.com/how-to-tune-a-machine-learning-algorithm-in-weka/
# Parsing URL:  https://machinelearningmastery.com/quick-and-dirty-data-analysis-for-your-machine-learning-problem/
# Parsing URL:  https://machinelearningmastery.com/design-and-run-your-first-experiment-in-weka/
# Parsing URL:  https://machinelearningmastery.com/how-to-choose-the-right-test-options-when-evaluating-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/how-to-run-your-first-classifier-in-weka/
# Parsing URL:  https://machinelearningmastery.com/process-for-working-through-machine-learning-problems/
# Parsing URL:  https://machinelearningmastery.com/why-you-should-be-spot-checking-algorithms-on-your-machine-learning-problems/
# Parsing URL:  https://machinelearningmastery.com/what-is-the-weka-machine-learning-workbench/
# Parsing URL:  https://machinelearningmastery.com/how-to-get-the-most-from-machine-learning-books-and-courses/
# Parsing URL:  https://machinelearningmastery.com/mistakes-programmers-make-when-starting-in-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/6-practical-books-for-beginning-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/how-to-implement-a-machine-learning-algorithm/
# Parsing URL:  https://machinelearningmastery.com/applied-machine-learning-is-a-meritocracy/
# Parsing URL:  https://machinelearningmastery.com/what-if-im-not-a-good-programmer/
# Parsing URL:  https://machinelearningmastery.com/what-if-i-dont-have-a-degree/
# Parsing URL:  https://machinelearningmastery.com/what-if-im-not-good-at-mathematics/
# Parsing URL:  https://machinelearningmastery.com/how-to-learn-a-machine-learning-algorithm/
# Parsing URL:  https://machinelearningmastery.com/hands-on-big-data-by-peter-norvig/
# Parsing URL:  https://machinelearningmastery.com/reproducible-machine-learning-results-by-default/
# Parsing URL:  https://machinelearningmastery.com/what-is-data-mining-and-kdd/
# Parsing URL:  https://machinelearningmastery.com/self-study-machine-learning-projects/
# Parsing URL:  https://machinelearningmastery.com/how-to-use-machine-learning-results/
# Parsing URL:  https://machinelearningmastery.com/how-to-identify-outliers-in-your-data/
# Parsing URL:  https://machinelearningmastery.com/how-to-improve-machine-learning-results/
# Parsing URL:  https://machinelearningmastery.com/how-to-evaluate-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/how-to-prepare-data-for-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/how-to-define-your-machine-learning-problem/
# Parsing URL:  https://machinelearningmastery.com/data-learning-and-modeling/
# Parsing URL:  https://machinelearningmastery.com/where-does-machine-learning-fit-in/
# Parsing URL:  https://machinelearningmastery.com/programmers-should-get-into-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-is-popular/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-is-fascinating/
# Parsing URL:  https://machinelearningmastery.com/machine-learning-matters/
# Parsing URL:  https://machinelearningmastery.com/self-study-guide-to-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/why-get-into-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/programmers-can-get-into-machine-learning/
# Parsing URL:  https://machinelearningmastery.com/best-machine-learning-resources-for-getting-started/
# Parsing URL:  https://machinelearningmastery.com/a-tour-of-machine-learning-algorithms/
# Parsing URL:  https://machinelearningmastery.com/practical-machine-learning-problems/
# Parsing URL:  https://machinelearningmastery.com/what-is-machine-learning/

# %%
### Step 6: Download all articles in Machine Learning Mastery articles folder ###

for entry in raw_json:
    file_name = "Machine Learning Mastery articles/" + entry['title'] + ".html"
    with open(file_name, 'w') as outfile:
        outfile.write(str(entry['content']))
        outfile.close()
print("All HTML files downloaded!!!")
# Out:
# All HTML files downloaded!!!

# %%
# Out:
# {'title': 'A Gentle Introduction to Early Stopping to Avoid Overtraining Deep Learning Neural Network Models', 'link': 'https://machinelearningmastery.com/early-stopping-to-avoid-overtraining-neural-network-models/', 'content': 'a gentle introduction to early stopping to avoid overtraining deep learning neural network models{"@context":"https:\\/\\/schema.org","@type":"organization","url":"https:\\/\\/machinelearningmastery.com\\/","sameas":["https:\\/\\/www.facebook.com\\/machine-learning-mastery-1429846323896563\\/","https:\\/\\/www.linkedin.com\\/in\\/jasonbrownlee","https:\\/\\/plus.google.com\\/u\\/0\\/b\\/117073416089354242117\\/+machinelearningmasteryhome\\/","https:\\/\\/twitter.com\\/teachthemachine"],"@id":"https:\\/\\/machinelearningmastery.com\\/#organization","name":"machine learning mastery","logo":"https:\\/\\/machinelearningmastery.com\\/wp-content\\/uploads\\/2016\\/09\\/cropped-icon.png"}window._wpemojisettings = {"baseurl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/11\\/72x72\\/","ext":".png","svgurl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/11\\/svg\\/","svgext":".svg","source":{"concatemoji":"https:\\/\\/machinelearningmastery.com\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=4.9.8"}};!function(a,b,c){function d(a,b){var c=string.fromcharcode;l.clearrect(0,0,k.width,k.height),l.filltext(c.apply(this,a),0,0);var d=k.todataurl();l.clearrect(0,0,k.width,k.height),l.filltext(c.apply(this,b),0,0);var e=k.todataurl();return d===e}function e(a){var b;if(!l||!l.filltext)return!1;switch(l.textbaseline="top",l.font="600 32px arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createelement("script");c.src=a,c.defer=c.type="text/javascript",b.getelementsbytagname("head")[0].appendchild(c)}var g,h,i,j,k=b.createelement("canvas"),l=k.getcontext&&k.getcontext("2d");for(j=array("flag","emoji"),c.supports={everything:!0,everythingexceptflag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingexceptflag=c.supports.everythingexceptflag&&c.supports[j[i]]);c.supports.everythingexceptflag=c.supports.everythingexceptflag&&!c.supports.flag,c.domready=!1,c.readycallback=function(){c.domready=!0},c.supports.everything||(h=function(){c.readycallback()},b.addeventlistener?(b.addeventlistener("domcontentloaded",h,!1),a.addeventlistener("load",h,!1)):(a.attachevent("onload",h),b.attachevent("onreadystatechange",function(){"complete"===b.readystate&&c.readycallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojisettings);img.wp-smiley,img.emoji {display: inline !important;border: none !important;box-shadow: none !important;height: 1em !important;width: 1em !important;margin: 0 .07em !important;vertical-align: -0.1em !important;background: none !important;padding: 0 !important;}.wpautoterms-footer{background-color:#ffffff;text-align:center;}.wpautoterms-footer a{color:#000000;font-family:arial, sans-serif;font-size:14px;}.wpautoterms-footer .separator{color:#cccccc;font-family:arial, sans-serif;font-size:14px;}/* <![cdata[ */var crayonsyntaxsettings = {"version":"_2.7.2_beta","is_admin":"0","ajaxurl":"https:\\/\\/machinelearningmastery.com\\/wp-admin\\/admin-ajax.php","prefix":"crayon-","setting":"crayon-setting","selected":"crayon-setting-selected","changed":"crayon-setting-changed","special":"crayon-setting-special","orig_value":"data-orig-value","debug":""};var crayonsyntaxstrings = {"copy":"press %s to copy, %s to paste","minimize":"click to expand code"};/* ]]> */\r  (function(i,s, ...

# %%
## Step 7: Write the plain texts to `Scrubbed MLM articles.json`
with open("Scrubbed MLM articles.json", 'w') as outfile:
    outfile.write(json.dumps(scrubbed_json, indent=4))
    outfile.close()
print("Plain texts written to Scrubbed MLM articles.json")
# Out:
# Plain texts written to Scrubbed MLM articles.json
